# %% [markdown]
# ##Библиотеки токенизации текста

# %%
# !pip install tensorflow-text spacy==3.3

# %%
import requests
import nltk
import spacy
import tensorflow as tf
import tensorflow_text as tf_text
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# Текст для токенизации

# %%
text = """
Илья Сегалович родился в семье советского геофизика В.И.Сегаловича. Детство провёл в
Казахстане. В Республиканской физико-математической школе познакомился с будущим сооснователем
«Яндекса» Аркадием Воложем. В 1981 году поступил в Московский геологоразведочный институт
им.Орджоникидзе.

С самого основания «Яндекса» и до своей смерти Илья Сегалович занимал позицию директора по
технологиям, был ключевым архитектором поисковых технологий и инициатором многих продуктов
компании, например, Яндекс.Директа, голосового помощника «Алиса» и беспилотного автомобиля.
"""

# %% [markdown]
# Разделение на токены

# %%
text.split()
# Out:
# ['Илья',
#  'Сегалович',
#  'родился',
#  'в',
#  'семье',
#  'советского',
#  'геофизика',
#  'В.И.Сегаловича.',
#  'Детство',
#  'провёл',
#  'в',
#  'Казахстане.',
#  'В',
#  'Республиканской',
#  'физико-математической',
#  'школе',
#  'познакомился',
#  'с',
#  'будущим',
#  'сооснователем',
#  '«Яндекса»',
#  'Аркадием',
#  'Воложем.',
#  'В',
#  '1981',
#  'году',
#  'поступил',
#  'в',
#  'Московский',
#  'геологоразведочный',
#  'институт',
#  'им.Орджоникидзе.',
#  'С',
#  'самого',
#  'основания',
#  '«Яндекса»',
#  'и',
#  'до',
#  'своей',
#  'смерти',
#  'Илья',
#  'Сегалович',
#  'занимал',
#  'позицию',
#  'директора',
#  'по',
#  'технологиям,',
#  'был',
#  'ключевым',
#  'архитектором',
#  'поисковых',
#  'технологий',
#  'и',
#  'инициатором',
#  'многих',
#  'продуктов',
#  'компании,',
#  'например,',
#  'Яндекс.Директа,',
#  'голосового',
#  'помощника',
#  '«Алиса»',
#  'и',
#  'беспилотного',
#  'автомобиля.']

# %% [markdown]
# ##Разделение на символы

# %%
list(text)
# Out:
# ['\n',
#  'И',
#  'л',
#  'ь',
#  'я',
#  ' ',
#  'С',
#  'е',
#  'г',
#  'а',
#  'л',
#  'о',
#  'в',
#  'и',
#  'ч',
#  ' ',
#  'р',
#  'о',
#  'д',
#  'и',
#  'л',
#  'с',
#  'я',
#  ' ',
#  'в',
#  ' ',
#  'с',
#  'е',
#  'м',
#  'ь',
#  'е',
#  ' ',
#  'с',
#  'о',
#  'в',
#  'е',
#  'т',
#  'с',
#  'к',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'г',
#  'е',
#  'о',
#  'ф',
#  'и',
#  'з',
#  'и',
#  'к',
#  'а',
#  ' ',
#  'В',
#  '.',
#  'И',
#  '.',
#  'С',
#  'е',
#  'г',
#  'а',
#  'л',
#  'о',
#  'в',
#  'и',
#  'ч',
#  'а',
#  '.',
#  ' ',
#  'Д',
#  'е',
#  'т',
#  'с',
#  'т',
#  'в',
#  'о',
#  ' ',
#  'п',
#  'р',
#  'о',
#  'в',
#  'ё',
#  'л',
#  ' ',
#  'в',
#  ' ',
#  '\n',
#  'К',
#  'а',
#  'з',
#  'а',
#  'х',
#  'с',
#  'т',
#  'а',
#  'н',
#  'е',
#  '.',
#  ' ',
#  'В',
#  ' ',
#  'Р',
#  'е',
#  'с',
#  'п',
#  'у',
#  'б',
#  'л',
#  'и',
#  'к',
#  'а',
#  'н',
#  'с',
#  'к',
#  'о',
#  'й',
#  ' ',
#  'ф',
#  'и',
#  'з',
#  'и',
#  'к',
#  'о',
#  '-',
#  'м',
#  'а',
#  'т',
#  'е',
#  'м',
#  'а',
#  'т',
#  'и',
#  'ч',
#  'е',
#  'с',
#  'к',
#  'о',
#  'й',
#  ' ',
#  'ш',
#  'к',
#  'о',
#  'л',
#  'е',
#  ' ',
#  'п',
#  'о',
#  'з',
#  'н',
#  'а',
#  'к',
#  'о',
#  'м',
#  'и',
#  'л',
#  'с',
#  'я',
#  ' ',
#  'с',
#  ' ',
#  'б',
#  'у',
#  'д',
#  'у',
#  'щ',
#  'и',
#  'м',
#  ' ',
#  'с',
#  'о',
#  'о',
#  'с',
#  'н',
#  'о',
#  'в',
#  'а',
#  'т',
#  'е',
#  'л',
#  'е',
#  'м',
#  ' ',
#  '\n',
#  '«',
#  'Я',
#  'н',
#  'д',
#  'е',
#  'к',
#  'с',
#  'а',
#  '»',
#  ' ',
#  'А',
#  'р',
#  'к',
#  'а',
#  'д',
#  'и',
#  'е',
#  'м',
#  ' ',
#  'В',
#  'о',
#  'л',
#  'о',
#  'ж',
#  'е',
#  'м',
#  '.',
#  ' ',
#  'В',
#  ' ',
#  '1',
#  '9',
#  '8',
#  '1',
#  ' ',
#  'г',
#  'о',
#  'д',
#  'у',
#  ' ',
#  'п',
#  'о',
#  'с',
#  'т',
#  'у',
#  'п',
#  'и',
#  'л',
#  ' ',
#  'в',
#  ' ',
#  'М',
#  'о',
#  'с',
#  'к',
#  'о',
#  'в',
#  'с',
#  'к',
#  'и',
#  'й',
#  ' ',
#  'г',
#  'е',
#  'о',
#  'л',
#  'о',
#  'г',
#  'о',
#  'р',
#  'а',
#  'з',
#  'в',
#  'е',
#  'д',
#  'о',
#  'ч',
#  'н',
#  'ы',
#  'й',
#  ' ',
#  'и',
#  'н',
#  'с',
#  'т',
#  'и',
#  'т',
#  'у',
#  'т',
#  ' ',
#  '\n',
#  'и',
#  'м',
#  '.',
#  'О',
#  'р',
#  'д',
#  'ж',
#  'о',
#  'н',
#  'и',
#  'к',
#  'и',
#  'д',
#  'з',
#  'е',
#  '.',
#  '\n',
#  '\n',
#  'С',
#  ' ',
#  'с',
#  'а',
#  'м',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'о',
#  'с',
#  'н',
#  'о',
#  'в',
#  'а',
#  'н',
#  'и',
#  'я',
#  ' ',
#  '«',
#  'Я',
#  'н',
#  'д',
#  'е',
#  'к',
#  'с',
#  'а',
#  '»',
#  ' ',
#  'и',
#  ' ',
#  'д',
#  'о',
#  ' ',
#  'с',
#  'в',
#  'о',
#  'е',
#  'й',
#  ' ',
#  'с',
#  'м',
#  'е',
#  'р',
#  'т',
#  'и',
#  ' ',
#  'И',
#  'л',
#  'ь',
#  'я',
#  ' ',
#  'С',
#  'е',
#  'г',
#  'а',
#  'л',
#  'о',
#  'в',
#  'и',
#  'ч',
#  ' ',
#  'з',
#  'а',
#  'н',
#  'и',
#  'м',
#  'а',
#  'л',
#  ' ',
#  'п',
#  'о',
#  'з',
#  'и',
#  'ц',
#  'и',
#  'ю',
#  ' ',
#  'д',
#  'и',
#  'р',
#  'е',
#  'к',
#  'т',
#  'о',
#  'р',
#  'а',
#  ' ',
#  'п',
#  'о',
#  ' ',
#  '\n',
#  'т',
#  'е',
#  'х',
#  'н',
#  'о',
#  'л',
#  'о',
#  'г',
#  'и',
#  'я',
#  'м',
#  ',',
#  ' ',
#  'б',
#  'ы',
#  'л',
#  ' ',
#  'к',
#  'л',
#  'ю',
#  'ч',
#  'е',
#  'в',
#  'ы',
#  'м',
#  ' ',
#  'а',
#  'р',
#  'х',
#  'и',
#  'т',
#  'е',
#  'к',
#  'т',
#  'о',
#  'р',
#  'о',
#  'м',
#  ' ',
#  'п',
#  'о',
#  'и',
#  'с',
#  'к',
#  'о',
#  'в',
#  'ы',
#  'х',
#  ' ',
#  'т',
#  'е',
#  'х',
#  'н',
#  'о',
#  'л',
#  'о',
#  'г',
#  'и',
#  'й',
#  ' ',
#  'и',
#  ' ',
#  'и',
#  'н',
#  'и',
#  'ц',
#  'и',
#  'а',
#  'т',
#  'о',
#  'р',
#  'о',
#  'м',
#  ' ',
#  'м',
#  'н',
#  'о',
#  'г',
#  'и',
#  'х',
#  ' ',
#  'п',
#  'р',
#  'о',
#  'д',
#  'у',
#  'к',
#  'т',
#  'о',
#  'в',
#  ' ',
#  '\n',
#  'к',
#  'о',
#  'м',
#  'п',
#  'а',
#  'н',
#  'и',
#  'и',
#  ',',
#  ' ',
#  'н',
#  'а',
#  'п',
#  'р',
#  'и',
#  'м',
#  'е',
#  'р',
#  ',',
#  ' ',
#  'Я',
#  'н',
#  'д',
#  'е',
#  'к',
#  'с',
#  '.',
#  'Д',
#  'и',
#  'р',
#  'е',
#  'к',
#  'т',
#  'а',
#  ',',
#  ' ',
#  'г',
#  'о',
#  'л',
#  'о',
#  'с',
#  'о',
#  'в',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'п',
#  'о',
#  'м',
#  'о',
#  'щ',
#  'н',
#  'и',
#  'к',
#  'а',
#  ' ',
#  '«',
#  'А',
#  'л',
#  'и',
#  'с',
#  'а',
#  '»',
#  ' ',
#  'и',
#  ' ',
#  'б',
#  'е',
#  'с',
#  'п',
#  'и',
#  'л',
#  'о',
#  'т',
#  'н',
#  'о',
#  'г',
#  'о',
#  ' ',
#  'а',
#  'в',
#  'т',
#  'о',
#  'м',
#  'о',
#  'б',
#  'и',
#  'л',
#  'я',
#  '.',
#  '\n']

# %% [markdown]
# ##Библиотека NLTK

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Токенизация по предложениям

# %%
sentences = sent_tokenize(text)

# %%
print(sentences)
# Out:
# ['\nИлья Сегалович родился в семье советского геофизика В.И.Сегаловича.', 'Детство провёл в \nКазахстане.', 'В Республиканской физико-математической школе познакомился с будущим сооснователем \n«Яндекса» Аркадием Воложем.', 'В 1981 году поступил в Московский геологоразведочный институт \nим.Орджоникидзе.', 'С самого основания «Яндекса» и до своей смерти Илья Сегалович занимал позицию директора по \nтехнологиям, был ключевым архитектором поисковых технологий и инициатором многих продуктов \nкомпании, например, Яндекс.Директа, голосового помощника «Алиса» и беспилотного автомобиля.']

# %% [markdown]
# Токенизация по словам

# %%
words = word_tokenize(text)

# %%
words
# Out:
# ['Илья',
#  'Сегалович',
#  'родился',
#  'в',
#  'семье',
#  'советского',
#  'геофизика',
#  'В.И.Сегаловича',
#  '.',
#  'Детство',
#  'провёл',
#  'в',
#  'Казахстане',
#  '.',
#  'В',
#  'Республиканской',
#  'физико-математической',
#  'школе',
#  'познакомился',
#  'с',
#  'будущим',
#  'сооснователем',
#  '«',
#  'Яндекса',
#  '»',
#  'Аркадием',
#  'Воложем',
#  '.',
#  'В',
#  '1981',
#  'году',
#  'поступил',
#  'в',
#  'Московский',
#  'геологоразведочный',
#  'институт',
#  'им.Орджоникидзе',
#  '.',
#  'С',
#  'самого',
#  'основания',
#  '«',
#  'Яндекса',
#  '»',
#  'и',
#  'до',
#  'своей',
#  'смерти',
#  'Илья',
#  'Сегалович',
#  'занимал',
#  'позицию',
#  'директора',
#  'по',
#  'технологиям',
#  ',',
#  'был',
#  'ключевым',
#  'архитектором',
#  'поисковых',
#  'технологий',
#  'и',
#  'инициатором',
#  'многих',
#  'продуктов',
#  'компании',
#  ',',
#  'например',
#  ',',
#  'Яндекс.Директа',
#  ',',
#  'голосового',
#  'помощника',
#  '«',
#  'Алиса',
#  '»',
#  'и',
#  'беспилотного',
#  'автомобиля',
#  '.']

# %% [markdown]
# ##Библиотека TensorFlow_Text

# %% [markdown]
# Разделение на слова

# %%
tokenizer = tf_text.WhitespaceTokenizer()
tokens = tokenizer.tokenize([text])
tokens.to_list()
# Out:
# [[b'\xd0\x98\xd0\xbb\xd1\x8c\xd1\x8f',
#   b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87',
#   b'\xd1\x80\xd0\xbe\xd0\xb4\xd0\xb8\xd0\xbb\xd1\x81\xd1\x8f',
#   b'\xd0\xb2',
#   b'\xd1\x81\xd0\xb5\xd0\xbc\xd1\x8c\xd0\xb5',
#   b'\xd1\x81\xd0\xbe\xd0\xb2\xd0\xb5\xd1\x82\xd1\x81\xd0\xba\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xb3\xd0\xb5\xd0\xbe\xd1\x84\xd0\xb8\xd0\xb7\xd0\xb8\xd0\xba\xd0\xb0',
#   b'\xd0\x92.\xd0\x98.\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87\xd0\xb0.',
#   b'\xd0\xaf\xd0\xbd\xd0\xb4\xd0\xb5\xd0\xba\xd1\x81.\xd0\x94\xd0\xb8\xd1\x80\xd0\xb5\xd0\xba\xd1\x82\xd0\xb0,',
#   b'\xd0\xb3\xd0\xbe\xd0\xbb\xd0\xbe\xd1\x81\xd0\xbe\xd0\xb2\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xbf\xd0\xbe\xd0\xbc\xd0\xbe\xd1\x89\xd0\xbd\xd0\xb8\xd0\xba\xd0\xb0',
#   b'\xc2\xab\xd0\x90\xd0\xbb\xd0\xb8\xd1\x81\xd0\xb0\xc2\xbb',
#   b'\xd0\xb8',
#   b'\xd0\xb1\xd0\xb5\xd1\x81\xd0\xbf\xd0\xb8\xd0\xbb\xd0\xbe\xd1\x82\xd0\xbd\xd0\xbe\xd0\xb3\xd0\xbe',
#   b'\xd0\xb0\xd0\xb2\xd1\x82\xd0\xbe\xd0\xbc\xd0\xbe\xd0\xb1\xd0\xb8\xd0\xbb\xd1\x8f.']]

# %%
[token.decode('utf-8') for token in tokens.to_list()[0]]
# Out:
# ['Илья',
#  'Сегалович',
#  'родился',
#  'в',
#  'семье',
#  'советского',
#  'геофизика',
#  'В.И.Сегаловича.',
#  'Детство',
#  'провёл',
#  'в',
#  'Казахстане.',
#  'В',
#  'Республиканской',
#  'физико-математической',
#  'школе',
#  'познакомился',
#  'с',
#  'будущим',
#  'сооснователем',
#  '«Яндекса»',
#  'Аркадием',
#  'Воложем.',
#  'В',
#  '1981',
#  'году',
#  'поступил',
#  'в',
#  'Московский',
#  'геологоразведочный',
#  'институт',
#  'им.Орджоникидзе.',
#  'С',
#  'самого',
#  'основания',
#  '«Яндекса»',
#  'и',
#  'до',
#  'своей',
#  'смерти',
#  'Илья',
#  'Сегалович',
#  'занимал',
#  'позицию',
#  'директора',
#  'по',
#  'технологиям,',
#  'был',
#  'ключевым',
#  'архитектором',
#  'поисковых',
#  'технологий',
#  'и',
#  'инициатором',
#  'многих',
#  'продуктов',
#  'компании,',
#  'например,',
#  'Яндекс.Директа,',
#  'голосового',
#  'помощника',
#  '«Алиса»',
#  'и',
#  'беспилотного',
#  'автомобиля.']

# %% [markdown]
# Разделение на части слов - токенизатор Sentencepiece

# %%
url = "https://github.com/tensorflow/text/blob/master/tensorflow_text/python/ops/test_data/test_oss_model.model?raw=true"
sp_model = requests.get(url).content

# %%
tokenizer = tf_text.SentencepieceTokenizer(sp_model, out_type=tf.string)
tokens = tokenizer.tokenize([text])
print(tokens.to_list())
# Out:
# [[b'\xe2\x96\x81', b'\n\xd0\x98\xd0\xbb\xd1\x8c\xd1\x8f', b'\xe2\x96\x81', b'\xd0\xa1\xd0\xb5\xd0\xb3\xd0\xb0\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xb8\xd1\x87', b'\xe2\x96\x81', b'\xd1\x80\xd0\xbe\xd0\xb4\xd0\xb8\xd0\xbb\xd1\x81\xd1\x8f', b'\xe2\x96\x81', b'\xd0\xb2', b'\xe2\x96\x81', b'\x
xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb3\xd0\xb8\xd1\x8f\xd0\xbc', b',', b'\xe2\x96\x81', b'\xd0\xb1\xd1\x8b\xd0\xbb', b'\xe2\x96\x81', b'\xd0\xba\xd0\xbb\xd1\x8e\xd1\x87\xd0\xb5\xd0\xb2\xd1\x8b\xd0\xbc', b'\xe2\x96\x81', b'\xd0\xb0\xd1\x80\xd1\x85\xd0\xb8\xd1\x82\xd0\xb5\xd0\xba\xd1\x82\xd0\xbe\xd ...

# %%
[token.decode('utf-8') for token in tokens.to_list()[0]]
# Out:
# ['▁',
#  '\nИлья',
#  '▁',
#  'Сегалович',
#  '▁',
#  'родился',
#  '▁',
#  'в',
#  '▁',
#  'семье',
#  '▁',
#  'советского',
#  '▁',
#  'геофизика',
#  '▁',
#  'В',
#  '.',
#  'И',
#  '.',
#  'Сегаловича',
#  '.',
#  '▁',
#  'Детство',
#  '▁',
#  'провёл',
#  '▁',
#  'в',
#  '▁',
#  '\nКазахстане',
#  '.',
#  '▁',
#  'В',
#  '▁',
#  'Республиканской',
#  '▁',
#  'физико',
#  '-',
#  'математической',
#  '▁',
#  'школе',
#  '▁',
#  'познакомился',
#  '▁',
#  'с',
#  '▁',
#  'будущим',
#  '▁',
#  'сооснователем',
#  '▁',
#  '\n«Яндекса»',
#  '▁',
#  'Аркадием',
#  '▁',
#  'Воложем',
#  '.',
#  '▁',
#  'В',
#  '▁',
#  '1',
#  '9',
#  '8',
#  '1',
#  '▁',
#  'году',
#  '▁',
#  'поступил',
#  '▁',
#  'в',
#  '▁',
#  'Московский',
#  '▁',
#  'геологоразведочный',
#  '▁',
#  'институт',
#  '▁',
#  '\nим',
#  '.',
#  'Орджоникидзе',
#  '.',
#  '\n\nС',
#  '▁',
#  'самого',
#  '▁',
#  'основания',
#  '▁',
#  '«Яндекса»',
#  '▁',
#  'и',
#  '▁',
#  'до',
#  '▁',
#  'своей',
#  '▁',
#  'смерти',
#  '▁',
#  'Илья',
#  '▁',
#  'Сегалович',
#  '▁',
#  'занимал',
#  '▁',
#  'позицию',
#  '▁',
#  'директора',
#  '▁',
#  'по',
#  '▁',
#  '\nтехнологиям',
#  ',',
#  '▁',
#  'был',
#  '▁',
#  'ключевым',
#  '▁',
#  'архитектором',
#  '▁',
#  'поисковых',
#  '▁',
#  'технологий',
#  '▁',
#  'и',
#  '▁',
#  'инициатором',
#  '▁',
#  'многих',
#  '▁',
#  'продуктов',
#  '▁',
#  '\nкомпании',
#  ',',
#  '▁',
#  'например',
#  ',',
#  '▁',
#  'Яндекс',
#  '.',
#  'Директа',
#  ',',
#  '▁',
#  'голосового',
#  '▁',
#  'помощника',
#  '▁',
#  '«Алиса»',
#  '▁',
#  'и',
#  '▁',
#  'беспилотного',
#  '▁',
#  'автомобиля',
#  '.',
#  '\n']

# %% [markdown]
# ##Библиотека spaCy

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# 2024-03-19 12:29:45.989927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEPRECATION: https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.3.0/ru_core_news_sm-3.3.0-py3-none-any.whl#egg=ru_core_news_sm==3.3.0 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Collecting ru-core-news-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.3.0/ru_core_news_sm-3.3.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.3.0) (3.3.0)
# Collecting pymorphy2>=0.9 (from ru-core-news-sm==3.3.0)
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.2 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1 (from pymorphy2>=0.9->ru-core-news-sm==3.3.0)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2>=0.9->ru-core-news-sm==3.3.0)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 38.9 MB/s eta 0:00:00
# Collecting docopt>=0.6 (from pymorphy2>=0.9->ru-core-news-sm==3.3.0)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.11.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.66.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (6.4.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2024.2.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->ru-core-news-sm==3.3.0) (2.1.5)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=c0576eb10560392681f68b8475c86f5c7ca6e6a94639ca5ca0514ca690edfb98
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 ru-core-news-sm-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
nlp = spacy.load('ru_core_news_sm')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)

# %%
doc = nlp(text)

# %%
for tocken in doc:
  print(tocken)
# Out:
# Илья
# Сегалович
# родился
# в
# семье
# советского
# геофизика
# В.И.Сегаловича
# .
# Детство
# провёл
# в
#
#
# Казахстане
# .
# В
# Республиканской
# физико
# -
# математической
# школе
# познакомился
# с
# будущим
# сооснователем
#
#
# «
# Яндекса
# »
# Аркадием
# Воложем
# .
# В
# 1981
# году
# поступил
# в
# Московский
# геологоразведочный
# институт
#
#
# им.
# Орджоникидзе
# .
#
#
#
# С
# самого
# основания
# «
# Яндекса
# »
# и
# до
# своей
# смерти
# Илья
# Сегалович
# занимал
# позицию
# директора
# по
#
#
# технологиям
# ,
# был
# ключевым
# архитектором
# поисковых
# технологий
# и
# инициатором
# многих
# продуктов
#
#
# компании
# ,
# например
# ,
# Яндекс
# .
# Директа
# ,
# голосового
# помощника
# «
# Алиса
# »
# и
# беспилотного
# автомобиля
# .
